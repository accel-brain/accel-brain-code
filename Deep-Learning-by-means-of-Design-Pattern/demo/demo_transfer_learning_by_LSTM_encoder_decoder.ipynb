# %% [markdown]
# # Problem setting: Sine Wave Prediction.
#
# This jupyter notebook demonstrates the function of **Encoder/Decoder based on LSTM**.
#
# In this demonstration, the training dataset is generated as follows.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from logging import getLogger, StreamHandler, NullHandler, DEBUG, ERROR

logger = getLogger("pydbm")
handler = StreamHandler()
handler.setLevel(DEBUG)
logger.setLevel(DEBUG)
logger.addHandler(handler)

# %%
def generate_sin(amp=0.5, sampling_freq=8000, freq=440, sec=5, extract_n=100):
    sin_list = []
    for n in np.arange(sampling_freq * sec):
        sin = amp * np.sin(2.0 * np.pi * freq * n / sampling_freq)
        sin_list.append(sin)
        if len(sin_list) > extract_n:
            break
    return np.array(sin_list[:extract_n])

# %%
fig = plt.figure(figsize=(20, 10))
plt.plot(generate_sin(freq=200) + np.random.normal(loc=0.0, scale=0.5, size=100))
plt.show()

# %%
# The number of sampled data.
sample_n = 1000
# The length of one cycle.
cycle_len = 20
# The number of features.
feature_n = 10

# The list of observed data points.
observed_arr_list = []
# The list of objective data.
target_arr_list = []

label_list = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
test_size = 0.3

for i in range(sample_n):
    f_list = []
    t_list = []
    label_n = np.random.randint(low=0, high=len(label_list))

    for j in range(feature_n):
        sin_arr = generate_sin(freq=int(label_list[label_n]), extract_n=cycle_len)
        noise_arr = np.random.normal(loc=0.0, scale=1.5, size=cycle_len)
        sin_arr += noise_arr
        f_arr = sin_arr[:int(sin_arr.shape[0] * (1 - test_size))]
        t_arr = sin_arr[int(sin_arr.shape[0] * (1 - test_size)):]
        f_list.append(f_arr)
        t_list.append(t_arr)

    observed_arr_list.append(f_list)
    target_arr_list.append(t_list)

observed_arr = np.array(observed_arr_list)
#observed_arr = observed_arr[:, 0, :, :]
#observed_arr = (observed_arr - observed_arr.mean()) / observed_arr.std()
target_arr = np.array(target_arr_list).astype(np.float64)
target_arr = target_arr.sum(axis=1)
observed_arr = (observed_arr - observed_arr.mean()) / observed_arr.std()
target_arr = (target_arr - target_arr.mean()) / target_arr.std()

from pydbm.activation.logistic_function import LogisticFunction
observed_arr = LogisticFunction().activate(observed_arr)
target_arr = observed_arr.copy()

observed_arr.shape, target_arr.shape
# Out:
# ((1000, 10, 14), (1000, 10, 14))

# %% [markdown]
# All Sine waves have been added randomly generated gussain signal noise.

# %%
fig = plt.figure(figsize=(20, 10))
for i in range(10):
    plt.plot(observed_arr[i])
plt.show();plt.close()

# %% [markdown]
# ## Problem solution: Encoder/Decoder based on LSTM.

# %%
# LSTM Graph which is-a `Synapse`.
from pydbm.synapse.recurrenttemporalgraph.lstm_graph import LSTMGraph
# Polymorphism.
from pydbm.synapse.recurrenttemporalgraph.lstm_graph import LSTMGraph as EncoderGraph
from pydbm.synapse.recurrenttemporalgraph.lstm_graph import LSTMGraph as DecoderGraph

# Loss function.
from pydbm.loss.mean_squared_error import MeanSquaredError
# SGD as a Loss function.
from pydbm.optimization.optparams.sgd import SGD
# Adam as a Loss function.
from pydbm.optimization.optparams.adam import Adam as EncoderAdam
from pydbm.optimization.optparams.adam import Adam as DecoderAdam
# Verification.
from pydbm.verification.verificate_function_approximation import VerificateFunctionApproximation
# LSTM model.
from pydbm.rnn.lstm_model import LSTMModel
# Polymorphism.
from pydbm.rnn.lstm_model import LSTMModel as Encoder
from pydbm.rnn.lstm_model import LSTMModel as Decoder
# Logistic Function as activation function.
from pydbm.activation.logistic_function import LogisticFunction
# Tanh Function as activation function.
from pydbm.activation.tanh_function import TanhFunction
# Encoder/Decoder
from pydbm.rnn.encoder_decoder_controller import EncoderDecoderController

# %%
# Init.
encoder_graph = EncoderGraph()

# Activation function in LSTM.
encoder_graph.observed_activating_function = TanhFunction()
encoder_graph.input_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
encoder_graph.forget_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
encoder_graph.output_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
encoder_graph.hidden_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
encoder_graph.output_activating_function = LogisticFunction()

# Initialization strategy.
# This method initialize each weight matrices and biases in Gaussian distribution: `np.random.normal(size=hoge) * 0.01`.
encoder_graph.create_rnn_cells(
    input_neuron_count=observed_arr.shape[-1],
    hidden_neuron_count=200,
    output_neuron_count=target_arr.shape[-1]
)

# %%
# Init.
decoder_graph = DecoderGraph()

# Activation function in LSTM.
decoder_graph.observed_activating_function = TanhFunction()
decoder_graph.input_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
decoder_graph.forget_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
decoder_graph.output_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
decoder_graph.hidden_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
decoder_graph.output_activating_function = LogisticFunction()

# Initialization strategy.
# This method initialize each weight matrices and biases in Gaussian distribution: `np.random.normal(size=hoge) * 0.01`.
decoder_graph.create_rnn_cells(
    input_neuron_count=200,
    hidden_neuron_count=observed_arr.shape[-1],
    output_neuron_count=200
)

# %%
encoder_opt_params = EncoderAdam()
encoder_opt_params.weight_limit = 0.5
encoder_opt_params.dropout_rate = 0.5

encoder = Encoder(
    # Delegate `graph` to `LSTMModel`.
    graph=encoder_graph,
    # The number of epochs in mini-batch training.
    epochs=100,
    # The batch size.
    batch_size=100,
    # Learning rate.
    learning_rate=1e-05,
    # Attenuate the `learning_rate` by a factor of this value every `attenuate_epoch`.
    learning_attenuate_rate=0.1,
    # Attenuate the `learning_rate` by a factor of `learning_attenuate_rate` every `attenuate_epoch`.
    attenuate_epoch=50,
    # Refereed maxinum step `t` in BPTT. If `0`, this class referes all past data in BPTT.
    bptt_tau=8,
    # Size of Test data set. If this value is `0`, the validation will not be executed.
    test_size_rate=0.3,
    # Loss function.
    computable_loss=MeanSquaredError(),
    # Optimizer.
    opt_params=encoder_opt_params,
    # Verification function.
    verificatable_result=VerificateFunctionApproximation(),
    tol=0.0
)

# %%
decoder_opt_params = DecoderAdam()
decoder_opt_params.weight_limit = 0.5
decoder_opt_params.dropout_rate = 0.5

decoder = Decoder(
    # Delegate `graph` to `LSTMModel`.
    graph=decoder_graph,
    # The number of epochs in mini-batch training.
    epochs=100,
    # The batch size.
    batch_size=100,
    # Learning rate.
    learning_rate=1e-05,
    # Attenuate the `learning_rate` by a factor of this value every `attenuate_epoch`.
    learning_attenuate_rate=0.1,
    # Attenuate the `learning_rate` by a factor of `learning_attenuate_rate` every `attenuate_epoch`.
    attenuate_epoch=50,
    # Refereed maxinum step `t` in BPTT. If `0`, this class referes all past data in BPTT.
    bptt_tau=8,
    # Size of Test data set. If this value is `0`, the validation will not be executed.
    test_size_rate=0.3,
    # Loss function.
    computable_loss=MeanSquaredError(),
    # Optimizer.
    opt_params=decoder_opt_params,
    # Verification function.
    verificatable_result=VerificateFunctionApproximation(),
    tol=0.0
)

# %%
encoder_decoder_controller = EncoderDecoderController(
    encoder=encoder,
    decoder=decoder,
    epochs=100,
    batch_size=100,
    learning_rate=1e-05,
    learning_attenuate_rate=0.1,
    attenuate_epoch=50,
    test_size_rate=0.3,
    computable_loss=MeanSquaredError(),
    verificatable_result=VerificateFunctionApproximation(),
    tol=0.0
)

# %%
# Learning.
encoder_decoder_controller.learn(observed_arr, target_arr)
# Out:
# Best params are updated.
# Epoch: 1
# Loss:
# Training: 0.30963749106 Test: 0.317818183397
# Epoch: 2
# Loss:
# Training: 0.327316276836 Test: 0.305845638758
# Epoch: 3
# Loss:
# Training: 0.315157186398 Test: 0.308422191465
# Epoch: 4
# Loss:
# Training: 0.309644579899 Test: 0.320024957682
# Epoch: 5
# Loss:
# Training: 0.322177155181 Test: 0.308684976334
# Epoch: 6
# Loss:
# Training: 0.332604972762 Test: 0.292766981732
# Best params are updated.
# Epoch: 7
# Loss:
# Training: 0.304917666048 Test: 0.293848096601
# Epoch: 8
# Loss:
# Training: 0.314326692389 Test: 0.292097598856
# Best params are updated.
# Epoch: 9
# Loss:
# Training: 0.298786835337 Test: 0.281691108219
# Epoch: 10
# Loss:
# Training: 0.307880041459 Test: 0.295624801781
# Epoch: 11
# Loss:
# Training: 0.311169984913 Test: 0.27977249015
# Rolling mean of Loss (Window is 10):
# Training: 0.3142448897370288 Test: 0.30168245348229533
# Epoch: 12
# Loss:
# Training: 0.301306124371 Test: 0.285052942652
# Rolling mean of Loss (Window is 10):
# Training: 0.31439813912227954 Test: 0.29787788415760696
# Best params are updated.
# Epoch: 13
# Loss:
# Training: 0.292667063976 Test: 0.299434628999
# Rolling mean of Loss (Window is 10):
# Training: 0.31179712387576397 Test: 0.29579861454707534
# Best params are updated.
# Epoch: 14
# Loss:
# Training: 0.288270769399 Test: 0.287950862297
# Rolling mean of Loss (Window is 10):
# Training: 0.309548111633582 Test: 0.29489985830045773
# Epoch: 15
# Loss:
# Training: 0.297080277457 Test: 0.290625573567
# Rolling mean of Loss (Window is 10):
# Training: 0.30741073058361057 Test: 0.29169244876202305
# Best params are updated.
# Epoch: 16
# Loss:
# Training: 0.282443882046 Test: 0.282414310592
# Rolling mean of Loss (Window is 10):
# Training: 0.30490104281121266 Test: 0.28988650848528535
# Best params are updated.
# Epoch: 17
# Loss:
# Training: 0.279992642514 Test: 0.297926411325
# Rolling mean of Loss (Window is 10):
# Training: 0.2998849337395693 Test: 0.28885124137133483
# Epoch: 18
# Loss:
# Training: 0.295100472758 Test: 0.267023282176
# Rolling mean of Loss (Window is 10):
# Training: 0.29739243138612687 Test: 0.28925907284371777
# Best params are updated.
# Epoch: 19
# Loss:
# Training: 0.27536797175 Test: 0.267101210865
# Rolling mean of Loss (Window is 10):
# Training: 0.2954698094230504 Test: 0.28675164117572416
# Epoch: 20
# Loss:
# Training: 0.285091121367 Test: 0.277831756535
# Rolling mean of Loss (Window is 10):
# Training: 0.2931279230643688 Test: 0.2852926514403847
# Epoch: 21
# Loss:
# Training: 0.285138679878 Test: 0.274815182037
# Rolling mean of Loss (Window is 10):
# Training: 0.2908490310551787 Test: 0.2835133469157546
# Epoch: 22
# Loss:
# Training: 0.299558955824 Test: 0.270230824662
# Rolling mean of Loss (Window is 10):
# Training: 0.2882459005516951 Test: 0.2830176161044558
# Epoch: 23
# Loss:
# Training: 0.287892567837 Test: 0.28645085297
# Rolling mean of Loss (Window is 10):
# Training: 0.2880711836969903 Test: 0.2815354043054059
# Epoch: 24
# Loss:
# Training: 0.284538719935 Test: 0.275156723189
# Rolling mean of Loss (Window is 10):
# Training: 0.28759373408311734 Test: 0.2802370267025216
# Epoch: 25
# Loss:
# Training: 0.279091192649 Test: 0.288212107482
# Rolling mean of Loss (Window is 10):
# Training: 0.287220529136696 Test: 0.27895761279166675
# Epoch: 26
# Loss:
# Training: 0.301206127757 Test: 0.274928580575
# Rolling mean of Loss (Window is 10):
# Training: 0.2854216206558965 Test: 0.2787162661831809
# Epoch: 27
# Loss:
# Training: 0.286207425721 Test: 0.272064456995
# Rolling mean of Loss (Window is 10):
# Training: 0.2872978452270386 Test: 0.27796769318143033
# Epoch: 28
# Loss:
# Training: 0.278980404103 Test: 0.270629022078
# Rolling mean of Loss (Window is 10):
# Training: 0.28791932354774974 Test: 0.275381497748477
# Epoch: 29
# Loss:
# Training: 0.283376257054 Test: 0.278704423169
# Rolling mean of Loss (Window is 10):
# Training: 0.2863073166822349 Test: 0.275742071738684
# Best params are updated.
# Epoch: 30
# Loss:
# Training: 0.271101401955 Test: 0.266423510697
# Rolling mean of Loss (Window is 10):
# Training: 0.28710814521261246 Test: 0.27690239296905594
# Epoch: 31
# Loss:
# Training: 0.275924738216 Test: 0.280181102019
# Rolling mean of Loss (Window is 10):
# Training: 0.2857091732713739 Test: 0.27576156838528776
# Epoch: 32
# Loss:
# Training: 0.281292881557 Test: 0.2790515499
# Rolling mean of Loss (Window is 10):
# Training: 0.28478777910517644 Test: 0.2762981603834665
# Epoch: 33
# Loss:
# Training: 0.282902443644 Test: 0.280337520333
# Rolling mean of Loss (Window is 10):
# Training: 0.28296117167841417 Test: 0.27718023290729177
# Epoch: 34
# Loss:
# Training: 0.291217481444 Test: 0.26429468408
# Rolling mean of Loss (Window is 10):
# Training: 0.28246215925911616 Test: 0.2765688996435817
# Epoch: 35
# Loss:
# Training: 0.273452048367 Test: 0.305374467667
# Rolling mean of Loss (Window is 10):
# Training: 0.28313003541003634 Test: 0.2754826957326709
# Epoch: 36
# Loss:
# Training: 0.312345020728 Test: 0.296016462053
# Rolling mean of Loss (Window is 10):
# Training: 0.28256612098182593 Test: 0.2771989317512249
# Epoch: 37
# Loss:
# Training: 0.321758803149 Test: 0.314184557778
# Rolling mean of Loss (Window is 10):
# Training: 0.2836800102788417 Test: 0.2793077198990709
# Epoch: 38
# Loss:
# Training: 0.316311063227 Test: 0.30307669337
# Rolling mean of Loss (Window is 10):
# Training: 0.2872351480216716 Test: 0.28351972997731
# Epoch: 39
# Loss:
# Training: 0.331282846876 Test: 0.305731975602
# Rolling mean of Loss (Window is 10):
# Training: 0.2909682139340385 Test: 0.2867644971065512
# Epoch: 40
# Loss:
# Training: 0.31717681752 Test: 0.300908773343
# Rolling mean of Loss (Window is 10):
# Training: 0.2957588729162882 Test: 0.2894672523498673
# Epoch: 41
# Loss:
# Training: 0.318334701276 Test: 0.308015723245
# Rolling mean of Loss (Window is 10):
# Training: 0.3003664144728285 Test: 0.2929157786144281
# Epoch: 42
# Loss:
# Training: 0.294384735694 Test: 0.302368125039
# Rolling mean of Loss (Window is 10):
# Training: 0.3046074107788154 Test: 0.2956992407370593
# Epoch: 43
# Loss:
# Training: 0.304346012841 Test: 0.321240212563
# Rolling mean of Loss (Window is 10):
# Training: 0.30591659619260236 Test: 0.2980308982509907
# Epoch: 44
# Loss:
# Training: 0.345584505373 Test: 0.319305004902
# Rolling mean of Loss (Window is 10):
# Training: 0.30806095311231696 Test: 0.3021211674739178
# Epoch: 45
# Loss:
# Training: 0.316212713397 Test: 0.325808292883
# Rolling mean of Loss (Window is 10):
# Training: 0.31349765550514874 Test: 0.30762219955615594
# Epoch: 46
# Loss:
# Training: 0.338695331494 Test: 0.330597785441
# Rolling mean of Loss (Window is 10):
# Training: 0.31777372200813697 Test: 0.30966558207775063
# Epoch: 47
# Loss:
# Training: 0.345497032083 Test: 0.332723329204
# Rolling mean of Loss (Window is 10):
# Training: 0.32040875308479383 Test: 0.31312371441651915
# Epoch: 48
# Loss:
# Training: 0.353219837367 Test: 0.321485265493
# Rolling mean of Loss (Window is 10):
# Training: 0.3227825759781496 Test: 0.3149775915591528
# Epoch: 49
# Loss:
# Training: 0.335429797681 Test: 0.31746116162
# Rolling mean of Loss (Window is 10):
# Training: 0.32647345339218675 Test: 0.31681844877139687
# Epoch: 50
# Loss:
# Training: 0.322468038017 Test: 0.300635166558
# Rolling mean of Loss (Window is 10):
# Training: 0.3268881484726378 Test: 0.31799136737320804
# Epoch: 51
# Loss:
# Training: 0.301472749977 Test: 0.294016359291
# Rolling mean of Loss (Window is 10):
# Training: 0.3274172705222822 Test: 0.3179640066947419
# Epoch: 52
# Loss:
# Training: 0.309487464641 Test: 0.263384020995
# Rolling mean of Loss (Window is 10):
# Training: 0.32573107539239954 Test: 0.3165640702993964
# Epoch: 53
# Loss:
# Training: 0.27300992426 Test: 0.282257040854
# Rolling mean of Loss (Window is 10):
# Training: 0.32724134828701346 Test: 0.31266565989500517
# Epoch: 54
# Loss:
# Training: 0.291481820685 Test: 0.263835845426
# Rolling mean of Loss (Window is 10):
# Training: 0.32410773942888405 Test: 0.3087673427241787
# Epoch: 55
# Loss:
# Training: 0.285883512186 Test: 0.270835640135
# Rolling mean of Loss (Window is 10):
# Training: 0.31869747096009304 Test: 0.30322042677659394
# Epoch: 56
# Loss:
# Training: 0.279525284786 Test: 0.255485923821
# Rolling mean of Loss (Window is 10):
# Training: 0.3156645508390279 Test: 0.29772316150180356
# Epoch: 57
# Loss:
# Training: 0.280497105012 Test: 0.26140931691
# Rolling mean of Loss (Window is 10):
# Training: 0.30974754616823563 Test: 0.29021197533980225
# Best params are updated.
# Epoch: 58
# Loss:
# Training: 0.270975113808 Test: 0.261321797126
# Rolling mean of Loss (Window is 10):
# Training: 0.3032475534611446 Test: 0.2830805741104481
# Best params are updated.
# Epoch: 59
# Loss:
# Training: 0.270441125304 Test: 0.266197802
# Rolling mean of Loss (Window is 10):
# Training: 0.29502308110521763 Test: 0.277064227273771
# Epoch: 60
# Loss:
# Training: 0.277525675765 Test: 0.268514991538
# Rolling mean of Loss (Window is 10):
# Training: 0.288524213867582 Test: 0.27193789131178225
# Epoch: 61
# Loss:
# Training: 0.27124530808 Test: 0.272993539368
# Rolling mean of Loss (Window is 10):
# Training: 0.2840299776424414 Test: 0.26872587380975815
# Epoch: 62
# Loss:
# Training: 0.278372333835 Test: 0.263903485514
# Rolling mean of Loss (Window is 10):
# Training: 0.2810072334526952 Test: 0.26662359181738277
# Epoch: 63
# Loss:
# Training: 0.283097287643 Test: 0.268708222898
# Rolling mean of Loss (Window is 10):
# Training: 0.2778957203721315 Test: 0.2666755382692597
# Best params are updated.
# Epoch: 64
# Loss:
# Training: 0.269735698224 Test: 0.260758975644
# Rolling mean of Loss (Window is 10):
# Training: 0.27890445671042685 Test: 0.2653206564736483
# Epoch: 65
# Loss:
# Training: 0.282979694538 Test: 0.274192745376
# Rolling mean of Loss (Window is 10):
# Training: 0.27672984446434373 Test: 0.26501296949543884
# Best params are updated.
# Epoch: 66
# Loss:
# Training: 0.263242123517 Test: 0.27308205173
# Rolling mean of Loss (Window is 10):
# Training: 0.2764394626994812 Test: 0.26534868001948525
# Epoch: 67
# Loss:
# Training: 0.2695021697 Test: 0.250366125438
# Rolling mean of Loss (Window is 10):
# Training: 0.27481114657257566 Test: 0.26710829281039095
# Epoch: 68
# Loss:
# Training: 0.269707978991 Test: 0.257660932877
# Rolling mean of Loss (Window is 10):
# Training: 0.2737116530414183 Test: 0.26600397366316275
# Epoch: 69
# Loss:
# Training: 0.265238384147 Test: 0.261852810239
# Rolling mean of Loss (Window is 10):
# Training: 0.27358493955977164 Test: 0.2656378872382408
# Epoch: 70
# Loss:
# Training: 0.272314299719 Test: 0.264819447596
# Rolling mean of Loss (Window is 10):
# Training: 0.27306466544401015 Test: 0.26520338806211535
# Epoch: 71
# Loss:
# Training: 0.268044576673 Test: 0.257909335947
# Rolling mean of Loss (Window is 10):
# Training: 0.27254352783936825 Test: 0.2648338336679375
# Epoch: 72
# Loss:
# Training: 0.270842102277 Test: 0.276604949373
# Rolling mean of Loss (Window is 10):
# Training: 0.2722234546987463 Test: 0.2633254133258438
# Epoch: 73
# Loss:
# Training: 0.27015957508 Test: 0.259393654711
# Rolling mean of Loss (Window is 10):
# Training: 0.2714704315429622 Test: 0.26459555971169085
# Epoch: 74
# Loss:
# Training: 0.270577678608 Test: 0.258842860569
# Rolling mean of Loss (Window is 10):
# Training: 0.27017666028666143 Test: 0.26366410289296754
# Best params are updated.
# Epoch: 75
# Loss:
# Training: 0.260109243638 Test: 0.264140874176
# Rolling mean of Loss (Window is 10):
# Training: 0.27026085832506525 Test: 0.2634724913854584
# Epoch: 76
# Loss:
# Training: 0.263794364188 Test: 0.253160847242
# Rolling mean of Loss (Window is 10):
# Training: 0.26797381323505365 Test: 0.2624673042654524
# Epoch: 77
# Loss:
# Training: 0.274012173786 Test: 0.263575235688
# Rolling mean of Loss (Window is 10):
# Training: 0.26802903730216315 Test: 0.2604751838166576
# Epoch: 78
# Loss:
# Training: 0.265582982722 Test: 0.256880270791
# Rolling mean of Loss (Window is 10):
# Training: 0.2684800377107175 Test: 0.2617960948416171
# Epoch: 79
# Loss:
# Training: 0.260644647178 Test: 0.255974974319
# Rolling mean of Loss (Window is 10):
# Training: 0.2680675380837319 Test: 0.26171802863308924
# Epoch: 80
# Loss:
# Training: 0.265777158359 Test: 0.256369801194
# Rolling mean of Loss (Window is 10):
# Training: 0.2676081643868858 Test: 0.26113024504106047
# Epoch: 81
# Loss:
# Training: 0.263241804202 Test: 0.261489105925
# Rolling mean of Loss (Window is 10):
# Training: 0.2669544502508532 Test: 0.2602852804008241
# Best params are updated.
# Epoch: 82
# Loss:
# Training: 0.258364988332 Test: 0.268142600786
# Rolling mean of Loss (Window is 10):
# Training: 0.2664741730037071 Test: 0.2606432573986611
# Epoch: 83
# Loss:
# Training: 0.276589863762 Test: 0.261624953373
# Rolling mean of Loss (Window is 10):
# Training: 0.26522646160917135 Test: 0.2597970225400127
# Best params are updated.
# Epoch: 84
# Loss:
# Training: 0.25791955186 Test: 0.259563001859
# Rolling mean of Loss (Window is 10):
# Training: 0.2658694904774287 Test: 0.2600201524062142
# Epoch: 85
# Loss:
# Training: 0.265912188654 Test: 0.250483471745
# Rolling mean of Loss (Window is 10):
# Training: 0.26460367780267696 Test: 0.2600921665352435
# Epoch: 86
# Loss:
# Training: 0.266739999763 Test: 0.263859135547
# Rolling mean of Loss (Window is 10):
# Training: 0.2651839723043653 Test: 0.25872642629216747
# Epoch: 87
# Loss:
# Training: 0.259697100319 Test: 0.264317993256
# Rolling mean of Loss (Window is 10):
# Training: 0.2654785358617914 Test: 0.25979625512266225
# Epoch: 88
# Loss:
# Training: 0.269957449415 Test: 0.267999783473
# Rolling mean of Loss (Window is 10):
# Training: 0.2640470285151089 Test: 0.2598705308794877
# Epoch: 89
# Loss:
# Training: 0.258316502083 Test: 0.261900030316
# Rolling mean of Loss (Window is 10):
# Training: 0.2644844751844257 Test: 0.26098248214760844
# Epoch: 90
# Loss:
# Training: 0.271386613054 Test: 0.26704735599
# Rolling mean of Loss (Window is 10):
# Training: 0.26425166067485384 Test: 0.26157498774738197
# Best params are updated.
# Epoch: 91
# Loss:
# Training: 0.251345192914 Test: 0.256034657302
# Rolling mean of Loss (Window is 10):
# Training: 0.26481260614440505 Test: 0.2626427432270204
# Epoch: 92
# Loss:
# Training: 0.255398887923 Test: 0.261077916181
# Rolling mean of Loss (Window is 10):
# Training: 0.2636229450155808 Test: 0.2620972983647072
# Epoch: 93
# Loss:
# Training: 0.267848224831 Test: 0.26937720094
# Rolling mean of Loss (Window is 10):
# Training: 0.2633263349746895 Test: 0.2613908299041832
# Epoch: 94
# Loss:
# Training: 0.258204561801 Test: 0.259272999586
# Rolling mean of Loss (Window is 10):
# Training: 0.26245217108157876 Test: 0.2621660546608548
# Epoch: 95
# Loss:
# Training: 0.266239868245 Test: 0.262828531003
# Rolling mean of Loss (Window is 10):
# Training: 0.26248067207568065 Test: 0.262137054433551
# Epoch: 96
# Loss:
# Training: 0.272896439293 Test: 0.267866672303
# Rolling mean of Loss (Window is 10):
# Training: 0.26251344003477894 Test: 0.2633715603594014
# Epoch: 97
# Loss:
# Training: 0.271328360898 Test: 0.256716921694
# Rolling mean of Loss (Window is 10):
# Training: 0.2631290839877803 Test: 0.26377231403499557
# Epoch: 98
# Loss:
# Training: 0.267142461138 Test: 0.261861183567
# Rolling mean of Loss (Window is 10):
# Training: 0.2642922100457138 Test: 0.2630122068787576
# Epoch: 99
# Loss:
# Training: 0.270846301921 Test: 0.256889293571
# Rolling mean of Loss (Window is 10):
# Training: 0.2640107112180262 Test: 0.2623983468881705
# Epoch: 100
# Loss:
# Training: 0.264797270428 Test: 0.291857047319
# Rolling mean of Loss (Window is 10):
# Training: 0.2652636912018531 Test: 0.2618972732136005
# Best params are saved.
# end.

# %%
# Logging the loss.
fig = plt.figure(figsize=(20, 12))
plt.ylabel("MSE")
plt.xlabel("epoch")
plt.plot(encoder_decoder_controller.verificatable_result.logs_df.train_loss.values, label="Loss in Training.")
plt.plot(encoder_decoder_controller.verificatable_result.logs_df.test_loss.values, label="Loss in Test.")
plt.legend()
plt.show();plt.close()

# %%
encoder_decoder_controller.verificatable_result.logs_df.tail(10)
# Out:
#     train_loss  test_loss
# 90    0.251345   0.256035
# 91    0.255399   0.261078
# 92    0.267848   0.269377
# 93    0.258205   0.259273
# 94    0.266240   0.262829
# 95    0.272896   0.267867
# 96    0.271328   0.256717
# 97    0.267142   0.261861
# 98    0.270846   0.256889
# 99    0.264797   0.291857

# %% [markdown]
# ## Problem solution: Save pre-learned parameters

# %%
encoder_graph.save_pre_learned_params("/var/tmp/encoder.npz")
decoder_graph.save_pre_learned_params("/var/tmp/decoder.npz")

# %% [markdown]
# ## Problem solution: Transfer Learning

# %%
# Init.
encoder_graph = EncoderGraph()

# Activation function in LSTM.
encoder_graph.observed_activating_function = TanhFunction()
encoder_graph.input_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
encoder_graph.forget_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
encoder_graph.output_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
encoder_graph.hidden_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
encoder_graph.output_activating_function = LogisticFunction()

# Transfer Learning.
encoder_graph.load_pre_learned_params("/var/tmp/encoder.npz")

# Init.
decoder_graph = DecoderGraph()

# Activation function in LSTM.
decoder_graph.observed_activating_function = TanhFunction()
decoder_graph.input_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
decoder_graph.forget_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
decoder_graph.output_gate_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
decoder_graph.hidden_activating_function = LogisticFunction(normalize_flag=False, normalization_mode="min_max")
decoder_graph.output_activating_function = LogisticFunction()

# Transfer Learning.
decoder_graph.load_pre_learned_params("/var/tmp/decoder.npz")

encoder_opt_params = EncoderAdam()
encoder_opt_params.weight_limit = 0.5
encoder_opt_params.dropout_rate = 0.5

encoder = Encoder(
    # Delegate `graph` to `LSTMModel`.
    graph=encoder_graph,
    # The number of epochs in mini-batch training.
    epochs=30,
    # The batch size.
    batch_size=100,
    # Learning rate.
    learning_rate=1e-05,
    # Attenuate the `learning_rate` by a factor of this value every `attenuate_epoch`.
    learning_attenuate_rate=0.1,
    # Attenuate the `learning_rate` by a factor of `learning_attenuate_rate` every `attenuate_epoch`.
    attenuate_epoch=50,
    # Refereed maxinum step `t` in BPTT. If `0`, this class referes all past data in BPTT.
    bptt_tau=8,
    # Size of Test data set. If this value is `0`, the validation will not be executed.
    test_size_rate=0.3,
    # Loss function.
    computable_loss=MeanSquaredError(),
    # Optimizer.
    opt_params=encoder_opt_params,
    # Verification function.
    verificatable_result=VerificateFunctionApproximation(),
    tol=0.0
)

decoder_opt_params = DecoderAdam()
decoder_opt_params.weight_limit = 0.5
decoder_opt_params.dropout_rate = 0.5

decoder = Decoder(
    # Delegate `graph` to `LSTMModel`.
    graph=decoder_graph,
    # The number of epochs in mini-batch training.
    epochs=30,
    # The batch size.
    batch_size=100,
    # Learning rate.
    learning_rate=1e-05,
    # Attenuate the `learning_rate` by a factor of this value every `attenuate_epoch`.
    learning_attenuate_rate=0.1,
    # Attenuate the `learning_rate` by a factor of `learning_attenuate_rate` every `attenuate_epoch`.
    attenuate_epoch=50,
    # Refereed maxinum step `t` in BPTT. If `0`, this class referes all past data in BPTT.
    bptt_tau=8,
    # Size of Test data set. If this value is `0`, the validation will not be executed.
    test_size_rate=0.3,
    # Loss function.
    computable_loss=MeanSquaredError(),
    # Optimizer.
    opt_params=decoder_opt_params,
    # Verification function.
    verificatable_result=VerificateFunctionApproximation(),
    tol=0.0
)

encoder_decoder_controller = EncoderDecoderController(
    encoder=encoder,
    decoder=decoder,
    epochs=30,
    batch_size=100,
    learning_rate=1e-05,
    learning_attenuate_rate=0.1,
    attenuate_epoch=50,
    test_size_rate=0.3,
    computable_loss=MeanSquaredError(),
    verificatable_result=VerificateFunctionApproximation(),
    tol=0.0
)

# %%
# Learning.
encoder_decoder_controller.learn(observed_arr, target_arr)
# Out:
# Best params are updated.
# Epoch: 1
# Loss:
# Training: 0.260395387237 Test: 0.252904219899
# Epoch: 2
# Loss:
# Training: 0.273847323132 Test: 0.261166821505
# Epoch: 3
# Loss:
# Training: 0.270565949831 Test: 0.265332003711
# Epoch: 4
# Loss:
# Training: 0.268168679065 Test: 0.266595080312
# Epoch: 5
# Loss:
# Training: 0.268241682269 Test: 0.269550020867
# Epoch: 6
# Loss:
# Training: 0.266547028872 Test: 0.258210844998
# Epoch: 7
# Loss:
# Training: 0.268737467358 Test: 0.25310234576
# Epoch: 8
# Loss:
# Training: 0.267883321942 Test: 0.261581005397
# Best params are updated.
# Epoch: 9
# Loss:
# Training: 0.259786212022 Test: 0.266393004064
# Best params are updated.
# Epoch: 10
# Loss:
# Training: 0.256160533224 Test: 0.271640989902
# Epoch: 11
# Loss:
# Training: 0.261297091891 Test: 0.271859985381
# Rolling mean of Loss (Window is 10):
# Training: 0.2660333584952098 Test: 0.2626476336414322
# Epoch: 12
# Loss:
# Training: 0.26109168998 Test: 0.26460815595
# Rolling mean of Loss (Window is 10):
# Training: 0.2661235289606084 Test: 0.26454321018966687
# Epoch: 13
# Loss:
# Training: 0.273950601853 Test: 0.267858937369
# Rolling mean of Loss (Window is 10):
# Training: 0.2648479656454331 Test: 0.26488734363414695
# Epoch: 14
# Loss:
# Training: 0.273665598847 Test: 0.275724042791
# Rolling mean of Loss (Window is 10):
# Training: 0.26518643084758453 Test: 0.265140036999979
# Epoch: 15
# Loss:
# Training: 0.27217907781 Test: 0.257733951767
# Rolling mean of Loss (Window is 10):
# Training: 0.265736122825836 Test: 0.266052933247913
# Epoch: 16
# Loss:
# Training: 0.257800942113 Test: 0.261279127852
# Rolling mean of Loss (Window is 10):
# Training: 0.26612986237988145 Test: 0.26487132633795246
# Epoch: 17
# Loss:
# Training: 0.272465310557 Test: 0.270482538098
# Rolling mean of Loss (Window is 10):
# Training: 0.2652552537039662 Test: 0.2651781546233841
# Epoch: 18
# Loss:
# Training: 0.27413516927 Test: 0.266518603027
# Rolling mean of Loss (Window is 10):
# Training: 0.26562803802383994 Test: 0.266916173857222
# Epoch: 19
# Loss:
# Training: 0.273179441726 Test: 0.280402165639
# Rolling mean of Loss (Window is 10):
# Training: 0.2662532227566594 Test: 0.2674099336202106
# Epoch: 20
# Loss:
# Training: 0.272932963127 Test: 0.265241921421
# Rolling mean of Loss (Window is 10):
# Training: 0.2675925457271168 Test: 0.2688108497777033
# Epoch: 21
# Loss:
# Training: 0.260225312744 Test: 0.28139007972
# Rolling mean of Loss (Window is 10):
# Training: 0.2692697887174905 Test: 0.26817094292960403
# Epoch: 22
# Loss:
# Training: 0.26730072214 Test: 0.27219700527
# Rolling mean of Loss (Window is 10):
# Training: 0.2691626108028245 Test: 0.2691239523635042
# Epoch: 23
# Loss:
# Training: 0.268368779626 Test: 0.274301764078
# Rolling mean of Loss (Window is 10):
# Training: 0.26978351401881956 Test: 0.26988283729553475
# Epoch: 24
# Loss:
# Training: 0.270975044385 Test: 0.274088879538
# Rolling mean of Loss (Window is 10):
# Training: 0.26922533179608943 Test: 0.2705271199664141
# Epoch: 25
# Loss:
# Training: 0.264321740432 Test: 0.274134974084
# Rolling mean of Loss (Window is 10):
# Training: 0.2689562763498355 Test: 0.27036360364115136
# Epoch: 26
# Loss:
# Training: 0.268213624392 Test: 0.266976168308
# Rolling mean of Loss (Window is 10):
# Training: 0.26817054261210754 Test: 0.272003705872868
# Epoch: 27
# Loss:
# Training: 0.274008948951 Test: 0.264452779319
# Rolling mean of Loss (Window is 10):
# Training: 0.2692118108400506 Test: 0.2725734099184461
# Epoch: 28
# Loss:
# Training: 0.263448366055 Test: 0.269967973316
# Rolling mean of Loss (Window is 10):
# Training: 0.26936617467949353 Test: 0.27197043404056404
# Epoch: 29
# Loss:
# Training: 0.260072416134 Test: 0.270216072879
# Rolling mean of Loss (Window is 10):
# Training: 0.26829749435798367 Test: 0.2723153710693965
# Epoch: 30
# Loss:
# Training: 0.275753621552 Test: 0.261560590062
# Rolling mean of Loss (Window is 10):
# Training: 0.26698679179877016 Test: 0.27129676179331763
# Best params are saved.
# end.

# %%
# Logging the loss.
fig = plt.figure(figsize=(20, 12))
plt.ylabel("MSE")
plt.xlabel("epoch")
plt.plot(encoder_decoder_controller.verificatable_result.logs_df.train_loss.values, label="Loss in Training.")
plt.plot(encoder_decoder_controller.verificatable_result.logs_df.test_loss.values, label="Loss in Test.")
plt.legend()
plt.show();plt.close()
