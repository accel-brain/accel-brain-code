# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
def sigmoid(x):
    '''
    Sigmoid function.
    
    Args:
        x:    Observed data points.
    
    Returns:
        y
    '''
    return 1 / (1 + np.exp(-x))

# %%
x1 = np.arange(-10.0, 10.0, 0.1)
y1 = sigmoid(x1)

plt.plot(x1, y1)
plt.xlabel("Observed data points.")
plt.ylabel("Activation.")
plt.title("The sigmoid function.")
plt.show()

# %%
def derivative_sigmoid(x):
    '''
    derivative.
    
    Args:
        x:    observed data points.
    
    Returns:
        y.
    '''
    return (1 - sigmoid(x)) * sigmoid(x)

# %%
y1 = sigmoid(x1)
d1 = derivative_sigmoid(x1)

plt.plot(x1, y1, label="Activation.")
plt.plot(x1, d1, label="derivative.")
plt.xlabel("Observed data points.")
plt.ylabel("The results.")
plt.legend()
plt.title("The sigmoid function.")
plt.show()

# %%
def tanh(x):
    '''
    tanh function.
    
    Args:
        x:    Observed data points.
    
    Returns:
        y
    '''
    return np.tanh(x)

# %%
x2 = np.arange(-10.0, 10.0, 0.1)
y2 = tanh(x2)

plt.plot(x2, y2)
plt.xlabel("Observed data points.")
plt.ylabel("Activation.")
plt.title("The tanh function.")
plt.show()

# %%
def derivative_tanh(x):
    '''
    derivative.
    
    Args:
        x:    observed data points.
    
    Returns:
        y.
    '''
    return 1 - (tanh(x) ** 2)

# %%
x2 = np.arange(-10.0, 10.0, 0.1)
y2 = tanh(x2)
d2 = derivative_tanh(x2)

plt.plot(x2, y2, label="Activation.")
plt.plot(x2, d2, label="Derivative.")
plt.xlabel("Observed data points.")
plt.ylabel("The results.")
plt.title("The tanh function.")
plt.legend()
plt.show()

# %%
def relu(x):
    '''
    ReLu function.
    
    Args:
        x:    Observed data points.
    
    Returns:
        y
    '''
    return np.maximum(x, 0)

# %%
x3 = np.arange(-10.0, 10.0, 0.1)
y3 = relu(x3)

plt.plot(x3, y3)
plt.xlabel("Observed data points.")
plt.ylabel("Activation.")
plt.title("The ReLu function.")
plt.show()

# %%
import numpy as np

def linear_trans(x, w, b):
    '''
    Linear transfromation.
    
    Args:
        x:    Observed data points.
        w:    Weight matrix.
        b:    bias vector.
    
    Returns:
        y.
    '''
    y = np.dot(x, w) + b
    return y


# Init(Hidden layer).
w1 = np.random.normal(size=(5, 10))
b1 = np.random.normal(size=(10))
# Init(Output layer).
w2 = np.random.normal(size=(10, 5))
b2 = np.random.normal(size=(5))

# Observed data points.
x1 = np.random.normal(size=(20, 5))

# Forward in hidden layer.
x2 = linear_trans(x1, w1, b1)
# Activation in hidden layer.
x2 = sigmoid(x2)

# Forward in output layer.
x3 = linear_trans(x2, w2, b2)

# Activation in output layer.
y = sigmoid(x3)
y
# Out:
# array([[0.14554385, 0.08983504, 0.00502849, 0.36342321, 0.29903087],
#        [0.23713808, 0.08060786, 0.01149312, 0.35698337, 0.56908413],
#        [0.16855186, 0.02487783, 0.01205287, 0.68432023, 0.82365558],
#        [0.16874036, 0.05444207, 0.00861933, 0.37749126, 0.59808575],
#        [0.11588413, 0.18257238, 0.01541341, 0.47887417, 0.5649325 ],
#        [0.13101555, 0.08288924, 0.00559671, 0.31473179, 0.34415743],
#        [0.11406237, 0.06564668, 0.0062839 , 0.4027135 , 0.55010554],
#        [0.10445006, 0.01771749, 0.01476148, 0.66079748, 0.66036206],
#        [0.1069656 , 0.21582451, 0.03832905, 0.42869161, 0.67889403],
#        [0.08016741, 0.01778618, 0.03401875, 0.38548231, 0.94040078],
#        [0.14826568, 0.33220226, 0.01560678, 0.39360474, 0.3259018 ],
#        [0.1549999 , 0.05630997, 0.00727298, 0.53517146, 0.40214124],
#        [0.23785566, 0.28891437, 0.00707585, 0.42659826, 0.25426317],
#        [0.30763701, 0.08776753, 0.00582116, 0.41090849, 0.36572759],
#        [0.13522417, 0.16324923, 0.01897578, 0.24921405, 0.23515341],
#        [0.07644218, 0.13779424, 0.0094239 , 0.32173735, 0.19010002],
#        [0.34880581, 0.06121276, 0.01668458, 0.53547457, 0.54614931],
#        [0.03530216, 0.01916358, 0.06524417, 0.37992899, 0.94376014],
#        [0.2518155 , 0.25737887, 0.00447949, 0.45141265, 0.17895199],
#        [0.0948176 , 0.21984942, 0.02038734, 0.29321533, 0.72049748]])
