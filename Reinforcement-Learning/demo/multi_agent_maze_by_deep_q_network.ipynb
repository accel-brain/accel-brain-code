# %% [markdown]
# # Problem Setting: Maze Solving
#
# This notebook demonstrates a simple maze solving algorithm based on Deep Q-Learning. According to the Reinforcement learning theory, the Q-Learning algorithm allow the agent to search the goal in 2D maze map. The agent can search and learn by the reward values in each point.
#
# In relation to reinforcement learning theory, the state of agent is 2D position coordinates and the action is to dicide the direction of movement. Within the wall, the agent is movable in a cross direction and can advance by one point at a time. After moving into a new position, the agent can obtain a reward. On greedy searching, this extrinsically motivated agent performs in order to obtain some reward as high as possible. Each reward value is plot in map.
#
# The map data that agent will observe is as follow.
#
# $$\boldsymbol{M}_{reward} =
# \begin{pmatrix}
# r_{1,1} & \cdots & r_{1,j} & \cdots & r_{1,m} \\
# \vdots & \ddots &        &        & \vdots \\
# r_{i,1} &        & r_{i,j} & \cdots & r_{i,m} \\
# \vdots &        &        & \ddots & \vdots \\
# r_{n,1} & \cdots & r_{n,j} & \cdots & r_{n,m}
# \end{pmatrix}
# $$
#
# where $(i, j)$ is tuple of 2D position coordinates in the maze map. Then $r_{i,j}$ is reward value that the agent can get by arriving the point: $(i, j)$. This notebook defines the reward function as follows
#
# $$r_{i, j} = 1.0 - \sqrt{(i - G_i)^2 + (j - G_j)^2} - \mathcal{P}_{repeating}$$
#
# where $(G_i, G_j)$ is the tuple of goal point and $\mathcal{P}_{repeating}$ is a penalty point in the case that the agent will revisit points that the agent have already reached. If the agent reaches the goal, the reward is $1.0$. This will be maximum reward.
#
# The state of agent is $s_{i,j}$. In this case, the form of agent's state transition matrix is designed to correspond with $\boldsymbol{M}_{reward}$ as follow.
#
# $$\boldsymbol{M}_{state} =
# \begin{pmatrix}
# s_{1,1} & \cdots & s_{1,j} & \cdots & s_{1,m} \\
# \vdots & \ddots &        &        & \vdots \\
# s_{i,1} &        & s_{i,j} & \cdots & s_{i,m} \\
# \vdots &        &        & \ddots & \vdots \\
# s_{n,1} & \cdots & s_{n,j} & \cdots & s_{n,m}
# \end{pmatrix}
# $$
#
# The possible actions of agent can be limited by $s_{i,j}$. Agent can select adjacent elements in $\boldsymbol{M}_{state}$.
#
# So in this problem setting, the maze map data can be as generated below in detail.

# %% [markdown]
# ## Problem solution: Q-Learning algorithm.
#
# This notebook considers problem setteing in which an agent interacts with an environment $\mathcal{E}$, in this case the Maze solving, in a sequence of actions, observations and rewards. At each time-step the agent selects an action at from the set of legal game actions,
#
# $$\boldsymbol{M}_{action} =
# \begin{pmatrix}
# a_{1,1} & \cdots & a_{1,j} & \cdots & a_{1,m} \\
# \vdots & \ddots &        &        & \vdots \\
# a_{i,1} &        & a_{i,j} & \cdots & a_{i,m} \\
# \vdots &        &        & \ddots & \vdots \\
# a_{n,1} & \cdots & a_{n,j} & \cdots & a_{n,m}
# \end{pmatrix}
# $$.
#
# $\boldsymbol{M}_{state}$, $\boldsymbol{M}_{action}$, and $\boldsymbol{M}_{reward}$ can be assembled as a matrix of rank-3 of 3 channels and considered as a feature points which will be observed by the agent. The state/action-value function is as follows
#
# $$Q(s, a) = Q(\boldsymbol{M}_{state}, \boldsymbol{M}_{action}, \boldsymbol{M}_{reward})$$
#
# The goal of the agent is to interact with the Maze map by selecting actions in a way that maximises future rewards. We can make the standard assumption that future rewards are discounted by a factor of $\gamma$ per time-step, and define the future discounted return at time $t$ as $R_t = \sum_{t'=t}^{T}\gamma^{t'-t}r_{t'}$
# , where $T$ is the time-step at which the agent will reach the goal. This notebook defines the optimal state/action-value function $Q^{\ast}(s, a) = Q^{\ast}(\boldsymbol{M}_{state}, \boldsymbol{M}_{action}, \boldsymbol{M}_{reward})$ as the maximum expected return achievable by following any strategy, after seeing some state $s$ and then taking some action $a$, $Q^{\ast}(s, a) = \max \pi \mathbb{E}[R_t \mid s_t = s, a_t = a, \pi ]$, where $\pi$ is a policy mapping sequences to actions (or distributions over actions).
#
# The optimal state/action-value function obeys an important identity known as the Bellman equation. This is based on the following *intuition*: if the optimal value $Q^{\ast}(s', a')$ of the sequence $s'$ at the next time-step was known for all possible actions $a'$ , then the optimal strategy is to select the action $a'$ maximising the expected value of $r + \gamma Q^{\ast}(s', a')$,
#
# $$Q^{\ast}(s', a') = \mathbb{E}_{s' \sim \mathcal{E}}[r + \gamma \max_{a'} Q^{\ast}(s', a')\mid s, a]$$
#
# The basic idea behind many reinforcement learning algorithms is to estimate the state/action-value function, by using the Bellman equation as an iterative update,
#
# $$Q_{i+1}(s, a) = \mathbb{E}[r + \gamma \max_{a'}Q_i(s', a') \mid s, a]$$.
#
# Such *value iteration algorithms* converge to the optimal state/action-value function, $Q_i \rightarrow Q^{\ast}$ as $i \rightarrow \infty$. In practice, this basic approach is totally impractical, because the state/action-value function is estimated separately for each sequence, without any **generalisation**. Instead, it is common to use a **function approximator** to estimate the state/action-value function,
#
# $$Q(s, a; \theta) \approx Q^{\ast}(s, a)$$
#
# # Problem re-setting: Generalisation, or a function approximation.
#
# The Reinforcement learning theory presents several issues from a perspective of deep learning theory. Firstly, deep learning applications have required large amounts of handlabelled training data. Reinforcement learning algorithms, on the other hand, must be able to learn from a scalar reward signal that is frequently sparse, noisy and delayed.
#
# The difference between the two theories is not only the type of data but also the timing to be observed. The delay between taking actions and receiving rewards, which can be thousands of timesteps long, seems particularly daunting when compared to the direct association between inputs and targets found in supervised learning.
#
# Another issue is that most deep learning algorithms assume the data samples to be independent, while in reinforcement learning one typically encounters sequences of highly correlated states. Furthermore, in Reinforcement learning the data distribution changes as the algorithm learns new behaviours, which can be problematic for deep learning methods that assume a fixed underlying distribution.

# %% [markdown]
# ## Problem solution: Deep Q-Network.
#
# In this problem setting, the function of nerual network or deep learning is a function approximation with weights $\theta$ as a Q-Network. A Q-Network can be trained by minimising a loss functions $L_i(\theta_i)$ that changes at each iteration $i$,
#
# $$L_i(\theta_i) = \mathbb{E}_{s, a \sim \rho(\cdot)}[y_i - Q(s, a, \theta_i)]^2$$
#
# where $y_i = \mathbb{E}_{s' \sim \mathcal{E}}[r + \gamma \max_{a'} Q(s', a', \theta_{i-1}) \mid s, a]$ is the target for iteration $i$ and $\rho(\cdot)$ is a so-called behaviour distribution. This is probability distribution over states and actions. The parameters from the previous iteration $\theta_{i−1}$ are held fixed when optimising the loss function $L_i(\theta_i)$. Differentiating the loss function
# with respect to the weights we arrive at the following gradient,
#
# $$\nabla_{\theta_i}L_i(\theta_i) = \mathbb{E}_{s, a \sim \rho(\cdot);s' \sim \mathcal{E}}\left[\left(r + \gamma \max_{a'} Q(s', a'; \theta_{i-1}) - Q(s, a; \theta_i)\right)\nabla_{\theta_i}Q(s, a; \theta)\right]$$.
#
# Because of computational complexity with high rank matrix: $Q(s, a) = Q(\boldsymbol{M}_{state}, \boldsymbol{M}_{action}, \boldsymbol{M}_{reward})$, this notebook adopts a **Deep convolutional neural networks(Deep CNNs)** and implements with library: [accel-brain-base](https://github.com/accel-brain/accel-brain-code/tree/master/Accel-Brain-Base) which is Python library for building the CNNs.
#
# To simplify expression, the output from the Deep CNNs as a function approximator is an affine transformation is as follows
#
# $$y'_i = F_{activate}\left((\boldsymbol{M}_{state}, \boldsymbol{M}_{action}, \boldsymbol{M}_{reward}) \ast W_{\theta_{i}} + \vec{b}\right)$$
#
# where $\ast$ is a convolution operator. $W_{\theta_{i}}$ is weight matrix in CNNs and $\vec{b}$ is a bias vector. And $F_{activate}$ is an activation function such as Logistic function, Tanh function, or ReLu function.

# %% [markdown]
# # Issue: The pursuit-evasion game
#
# Expanding the search problem of the maze makes it possible to describe the pursuit-evasion game that  is a family of problems in mathematics and computer science in which one group attempts to track down members of another group in an environment.
#
# ## Problem solution: Re-entry the Deep Q-Network
#
# This problem can be re-described as the multi-agent control problem, which involves decomposing the global system state into an image like representation with information encoded in separate channels. This reformulation allows us to use convolutional neural networks to efficiently extract important features from the image-like state.
#
# Gupta, J. K. et al.(2017) proposed new algorithm which uses the image-like state representation of the multi-agent system as an input, and outputs the estimated Q-values for the agent in question. They described a number of implementation contributions that make training efficient and allow agents to learn directly from the behavior of other agents in the system.

# %% [markdown]
# ### Import modules and instantiate objects.
#
# Import Python modules from [accel-brain-base](https://github.com/accel-brain/accel-brain-code/tree/master/Accel-Brain-Base) and [pyqlearning](https://github.com/chimera0/accel-brain-code/tree/master/Reinforcement-Learning) and instantiate objects.

# %%
from pyqlearning.samplabledata.policysampler._mxnet.maze_multi_agent_policy import MazeMultiAgentPolicy
from accelbrainbase.computableloss._mxnet.l2_norm_loss import L2NormLoss
from accelbrainbase.controllablemodel._mxnet.dqlcontroller.dqn_controller import DQNController
from accelbrainbase.observabledata._mxnet.functionapproximator.function_approximator import FunctionApproximator
from accelbrainbase.noiseabledata._mxnet.gauss_noise import GaussNoise
from accelbrainbase.observabledata._mxnet.neural_networks import NeuralNetworks
from accelbrainbase.observabledata._mxnet.convolutional_neural_networks import ConvolutionalNeuralNetworks
from accelbrainbase.observabledata._mxnet.convolutionalneuralnetworks.mobilenet_v2 import MobileNetV2

# %%
import numpy as np
import mxnet as mx
import mxnet.ndarray as nd
import mxnet as mx
import mxnet.ndarray as nd
import numpy as np
import pandas as pd
from mxnet.gluon.nn import Conv2D
from mxnet.gluon.nn import BatchNorm
from mxnet import MXNetError
from logging import getLogger

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from logging import getLogger, StreamHandler, NullHandler, DEBUG, ERROR

logger = getLogger("accelbrainbase")
handler = StreamHandler()
handler.setLevel(DEBUG)
logger.setLevel(DEBUG)
logger.addHandler(handler)

# %%
enemy_num = 2

policy_sampler = MazeMultiAgentPolicy(
    batch_size=25,
    map_size=(20, 20), 
    moving_max_dist=3,
    memory_num=8,
    possible_n=5,
    repeating_penalty=0.5,
    enemy_num=enemy_num,
    enemy_moving_max_dist=2,
    ctx=mx.gpu(),
)

# %% [markdown]
# ### Setup hyperparameters.
#
# In relation to our problem setting, the function of `DQNController` is to solve Maze problem with Deep Q-Network. This object can be delegated `FunctionApproximator` and received hyperparameters.

# %%
computable_loss = L2NormLoss()
ctx = mx.gpu()

output_nn = NeuralNetworks(
    # is-a `ComputableLoss` or `mxnet.gluon.loss`.
    computable_loss=computable_loss,
    # `list` of int` of the number of units in hidden/output layers.
    units_list=[1],
    # `list` of act_type` in `mxnet.ndarray.Activation` or `mxnet.symbol.Activation` in input gate.
    activation_list=["sigmoid"],
    # `list` of `float` of dropout rate.
    dropout_rate_list=[0.0],
    # `list` of `mxnet.gluon.nn.BatchNorm`.
    hidden_batch_norm_list=[None],
    # `bool` for using bias or not in output layer(last hidden layer).
    output_no_bias_flag=True,
    # `bool` for using bias or not in all layer.
    all_no_bias_flag=True,
    # Call `mxnet.gluon.HybridBlock.hybridize()` or not.
    hybridize_flag=True,
    # `mx.gpu()` or `mx.cpu()`.
    ctx=ctx,
)

cnn = MobileNetV2(
    # is-a `ComputableLoss` or `mxnet.gluon.loss`.
    computable_loss=computable_loss,
    # is-a `mxnet.initializer.Initializer` for parameters of model. If `None`, it is drawing from the Xavier distribution.
    initializer=None,
    # `int` of the number of filters in input lauer.
    input_filter_n=32,
    # `tuple` or `int` of kernel size in input layer.
    input_kernel_size=(3, 3),
    # `tuple` or `int` of strides in input layer.
    input_strides=(1, 1),
    # `tuple` or `int` of zero-padding in input layer.
    input_padding=(1, 1),
    # `list` of information of bottleneck layers whose `dict` means ...
    # - `filter_rate`: `float` of filter expfilter.
    # - `filter_n`: `int` of the number of filters.
    # - `block_n`: `int` of the number of blocks.
    # - `stride`: `int` or `tuple` of strides.
    bottleneck_dict_list=[
        {
            "filter_rate": 1,
            "filter_n": 32,
            "block_n": 1,
            "stride": 1
        },
        {
            "filter_rate": 1,
            "filter_n": 32,
            "block_n": 2,
            "stride": 1
        },
    ],
    # `int` of the number of filters in hidden layers.
    hidden_filter_n=64,
    # `tuple` or `int` of pooling size in hidden layer.
    # If `None`, the pooling layer will not attatched in hidden layer.
    pool_size=None,
    # is-a `NeuralNetworks` or `mxnet.gluon.block.hybridblock.HybridBlock`.
    output_nn=output_nn,
    # `str` of name of optimizer.
    optimizer_name="sgd",
    # Call `mxnet.gluon.HybridBlock.hybridize()` or not.
    hybridize_flag=True,
    # `mx.gpu()` or `mx.cpu()`.
    ctx=ctx,
)

function_approximator = FunctionApproximator(
    model=cnn, 
    initializer=None,
    hybridize_flag=True,
    scale=1.0, 
    ctx=ctx, 
)

DQN = DQNController(
    function_approximator=function_approximator,
    policy_sampler=policy_sampler,
    computable_loss=L2NormLoss(),
    optimizer_name="SGD",
    learning_rate=1e-06,
    hybridize_flag=True,
    scale=1.0,
    ctx=ctx,
    initializer=None,
    recursive_learning_flag=False,
)
DQN.alpha_value = 0.5

# %% [markdown]
# ### Visualize map.
#
# Before executing `DQNController.lean()`, `MazePolicy` created a map at random and has `np.ndarray` of the data as `MazePolicy.map_arr`.

# %%
_ = plt.figure(figsize=(10, 10))
plt.imshow(DQN.policy_sampler.map_arr, cmap="gray")
plt.tick_params(labelbottom="off",bottom="off")
plt.tick_params(labelleft="off",left="off")
plt.show()
plt.close()

# %% [markdown]
# - Black squares represent a wall.
# - Light gray squares represent passages.
# - A dark gray square represents a start point.
# - A white squeare represents a goal point.

# %% [markdown]
# ### Schedule the learning.
#
# Determine the number of learning and the number of searches.

# %%
# Execute learning.
DQN.learn(
    # The number of searching.
    iter_n=500,
)
# Out:
# ----------------------------------------------------------------------------------------------------
# Iter: 1
# Reward value(mean): 0.72504115
# Predicted Q-value(mean): 0.523644
# Real Q-value(mean): 0.4737603
# Loss of Q-Value(mean): 2.0617168e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 2
# Reward value(mean): 0.7292766
# Predicted Q-value(mean): 0.52375174
# Real Q-value(mean): 0.47384524
# Loss of Q-Value(mean): 1.7836965e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 3
# Reward value(mean): 0.728559
# Predicted Q-value(mean): 0.47809395
# Real Q-value(mean): 0.47139058
# Loss of Q-Value(mean): 1.100064e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 4
# Reward value(mean): 0.7302
# Predicted Q-value(mean): 0.51544017
# Real Q-value(mean): 0.46830377
# Loss of Q-Value(mean): 3.0050587e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 5
# Reward value(mean): 0.7297518
# Predicted Q-value(mean): 0.51831526
# Real Q-value(mean): 0.4649027
# Loss of Q-Value(mean): 3.1955555e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 6
# Reward value(mean): 0.7301886
# Predicted Q-value(mean): 0.5139977
# Real Q-value(mean): 0.46937552
# Loss of Q-Value(mean): 3.461756e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 7
# Reward value(mean): 0.731175
# Predicted Q-value(mean): 0.5091178
# Real Q-value(mean): 0.47660252
# Loss of Q-Value(mean): 1.7963905e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 8
# Reward value(mean): 0.7300068
# Predicted Q-value(mean): 0.5176754
# Real Q-value(mean): 0.48479375
# Loss of Q-Value(mean): 8.749246e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 9
# Reward value(mean): 0.7314442
# Predicted Q-value(mean): 0.5206845
# Real Q-value(mean): 0.48650357
# Loss of Q-Value(mean): 1.1004145e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 10
# Reward value(mean): 0.7311237
# Predicted Q-value(mean): 0.5338014
# Real Q-value(mean): 0.49078074
# Loss of Q-Value(mean): 2.8453138e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 11
# Reward value(mean): 0.7300214
# Predicted Q-value(mean): 0.5181082
# Real Q-value(mean): 0.49154818
# Loss of Q-Value(mean): 7.813704e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 12
# Reward value(mean): 0.7312409
# Predicted Q-value(mean): 0.5314518
# Real Q-value(mean): 0.49410468
# Loss of Q-Value(mean): 2.9321487e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 13
# Reward value(mean): 0.72977376
# Predicted Q-value(mean): 0.5267114
# Real Q-value(mean): 0.49025327
# Loss of Q-Value(mean): 1.7108854e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 14
# Reward value(mean): 0.7287198
# Predicted Q-value(mean): 0.51414144
# Real Q-value(mean): 0.48927203
# Loss of Q-Value(mean): 8.1497155e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 15
# Reward value(mean): 0.7304734
# Predicted Q-value(mean): 0.49786568
# Real Q-value(mean): 0.4917078
# Loss of Q-Value(mean): 3.5373116e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 16
# Reward value(mean): 0.7301821
# Predicted Q-value(mean): 0.530723
# Real Q-value(mean): 0.49284184
# Loss of Q-Value(mean): 2.4075864e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 17
# Reward value(mean): 0.7298117
# Predicted Q-value(mean): 0.5182797
# Real Q-value(mean): 0.49310768
# Loss of Q-Value(mean): 1.3327211e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 18
# Reward value(mean): 0.73200625
# Predicted Q-value(mean): 0.5131709
# Real Q-value(mean): 0.4951556
# Loss of Q-Value(mean): 6.901853e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 19
# Reward value(mean): 0.72978884
# Predicted Q-value(mean): 0.5165165
# Real Q-value(mean): 0.4925804
# Loss of Q-Value(mean): 8.350895e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 20
# Reward value(mean): 0.72967345
# Predicted Q-value(mean): 0.5196448
# Real Q-value(mean): 0.4951667
# Loss of Q-Value(mean): 6.077378e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 21
# Reward value(mean): 0.72992605
# Predicted Q-value(mean): 0.5184063
# Real Q-value(mean): 0.49548936
# Loss of Q-Value(mean): 7.0988194e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 22
# Reward value(mean): 0.7291773
# Predicted Q-value(mean): 0.527037
# Real Q-value(mean): 0.4944548
# Loss of Q-Value(mean): 2.0202391e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 23
# Reward value(mean): 0.7308497
# Predicted Q-value(mean): 0.5257075
# Real Q-value(mean): 0.49518996
# Loss of Q-Value(mean): 1.1538476e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 24
# Reward value(mean): 0.728878
# Predicted Q-value(mean): 0.52808434
# Real Q-value(mean): 0.49188796
# Loss of Q-Value(mean): 1.5743328e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 25
# Reward value(mean): 0.7299997
# Predicted Q-value(mean): 0.5269306
# Real Q-value(mean): 0.4937707
# Loss of Q-Value(mean): 1.2250617e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 26
# Reward value(mean): 0.7304206
# Predicted Q-value(mean): 0.494427
# Real Q-value(mean): 0.49385995
# Loss of Q-Value(mean): 5.1642073e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 27
# Reward value(mean): 0.7296603
# Predicted Q-value(mean): 0.53567946
# Real Q-value(mean): 0.4950551
# Loss of Q-Value(mean): 1.2425222e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 28
# Reward value(mean): 0.7300018
# Predicted Q-value(mean): 0.5041626
# Real Q-value(mean): 0.4975504
# Loss of Q-Value(mean): 6.4229844e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 29
# Reward value(mean): 0.7309028
# Predicted Q-value(mean): 0.48682973
# Real Q-value(mean): 0.49353862
# Loss of Q-Value(mean): 2.4622339e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 30
# Reward value(mean): 0.7296382
# Predicted Q-value(mean): 0.5141958
# Real Q-value(mean): 0.49553168
# Loss of Q-Value(mean): 1.7860653e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 31
# Reward value(mean): 0.7296466
# Predicted Q-value(mean): 0.51520807
# Real Q-value(mean): 0.4963041
# Loss of Q-Value(mean): 8.396126e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 32
# Reward value(mean): 0.7305736
# Predicted Q-value(mean): 0.5095632
# Real Q-value(mean): 0.4970766
# Loss of Q-Value(mean): 1.0808302e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 33
# Reward value(mean): 0.72998625
# Predicted Q-value(mean): 0.49903923
# Real Q-value(mean): 0.49093646
# Loss of Q-Value(mean): 5.6702825e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 34
# Reward value(mean): 0.7310865
# Predicted Q-value(mean): 0.5084326
# Real Q-value(mean): 0.49610028
# Loss of Q-Value(mean): 5.6951335e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 35
# Reward value(mean): 0.72994316
# Predicted Q-value(mean): 0.51189756
# Real Q-value(mean): 0.491756
# Loss of Q-Value(mean): 1.1451937e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 36
# Reward value(mean): 0.7291807
# Predicted Q-value(mean): 0.5330944
# Real Q-value(mean): 0.49451816
# Loss of Q-Value(mean): 3.0293768e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 37
# Reward value(mean): 0.7296891
# Predicted Q-value(mean): 0.49907675
# Real Q-value(mean): 0.4957342
# Loss of Q-Value(mean): 1.059152e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 38
# Reward value(mean): 0.7289118
# Predicted Q-value(mean): 0.52861315
# Real Q-value(mean): 0.48956767
# Loss of Q-Value(mean): 1.4372757e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 39
# Reward value(mean): 0.7311703
# Predicted Q-value(mean): 0.52223384
# Real Q-value(mean): 0.4938424
# Loss of Q-Value(mean): 8.9210325e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 40
# Reward value(mean): 0.7304462
# Predicted Q-value(mean): 0.49489194
# Real Q-value(mean): 0.49374044
# Loss of Q-Value(mean): 6.015341e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 41
# Reward value(mean): 0.7300328
# Predicted Q-value(mean): 0.5101296
# Real Q-value(mean): 0.49331024
# Loss of Q-Value(mean): 8.08949e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 42
# Reward value(mean): 0.7301225
# Predicted Q-value(mean): 0.49343747
# Real Q-value(mean): 0.49598828
# Loss of Q-Value(mean): 4.8917964e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 43
# Reward value(mean): 0.73009735
# Predicted Q-value(mean): 0.5165237
# Real Q-value(mean): 0.49555096
# Loss of Q-Value(mean): 6.295146e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 44
# Reward value(mean): 0.73099875
# Predicted Q-value(mean): 0.51918596
# Real Q-value(mean): 0.49454215
# Loss of Q-Value(mean): 1.0528584e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 45
# Reward value(mean): 0.73041093
# Predicted Q-value(mean): 0.52672505
# Real Q-value(mean): 0.4925266
# Loss of Q-Value(mean): 4.086406e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 46
# Reward value(mean): 0.7303494
# Predicted Q-value(mean): 0.5181005
# Real Q-value(mean): 0.49455154
# Loss of Q-Value(mean): 1.0865345e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 47
# Reward value(mean): 0.73121953
# Predicted Q-value(mean): 0.526261
# Real Q-value(mean): 0.49622804
# Loss of Q-Value(mean): 1.567178e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 48
# Reward value(mean): 0.72957087
# Predicted Q-value(mean): 0.48809364
# Real Q-value(mean): 0.49464357
# Loss of Q-Value(mean): 8.667716e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 49
# Reward value(mean): 0.7294137
# Predicted Q-value(mean): 0.5374175
# Real Q-value(mean): 0.49353942
# Loss of Q-Value(mean): 2.2343105e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 50
# Reward value(mean): 0.7293568
# Predicted Q-value(mean): 0.5131771
# Real Q-value(mean): 0.4943337
# Loss of Q-Value(mean): 1.0763393e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 51
# Reward value(mean): 0.7293526
# Predicted Q-value(mean): 0.52340096
# Real Q-value(mean): 0.49401218
# Loss of Q-Value(mean): 1.378041e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 52
# Reward value(mean): 0.73065317
# Predicted Q-value(mean): 0.51386696
# Real Q-value(mean): 0.49582154
# Loss of Q-Value(mean): 4.8020775e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 53
# Reward value(mean): 0.72920775
# Predicted Q-value(mean): 0.48885643
# Real Q-value(mean): 0.49822778
# Loss of Q-Value(mean): 8.812802e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 54
# Reward value(mean): 0.7292093
# Predicted Q-value(mean): 0.48292872
# Real Q-value(mean): 0.49508137
# Loss of Q-Value(mean): 2.7522815e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 55
# Reward value(mean): 0.7304358
# Predicted Q-value(mean): 0.5208357
# Real Q-value(mean): 0.49451697
# Loss of Q-Value(mean): 1.6079246e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 56
# Reward value(mean): 0.73180234
# Predicted Q-value(mean): 0.50557053
# Real Q-value(mean): 0.49684775
# Loss of Q-Value(mean): 6.482834e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 57
# Reward value(mean): 0.7305494
# Predicted Q-value(mean): 0.5123263
# Real Q-value(mean): 0.49330816
# Loss of Q-Value(mean): 1.257497e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 58
# Reward value(mean): 0.7300886
# Predicted Q-value(mean): 0.47756034
# Real Q-value(mean): 0.49336445
# Loss of Q-Value(mean): 1.4738968e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 59
# Reward value(mean): 0.73034227
# Predicted Q-value(mean): 0.5282288
# Real Q-value(mean): 0.49596298
# Loss of Q-Value(mean): 6.159844e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 60
# Reward value(mean): 0.7316093
# Predicted Q-value(mean): 0.5238808
# Real Q-value(mean): 0.49426416
# Loss of Q-Value(mean): 1.9503215e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 61
# Reward value(mean): 0.7308827
# Predicted Q-value(mean): 0.5147308
# Real Q-value(mean): 0.4922905
# Loss of Q-Value(mean): 9.341894e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 62
# Reward value(mean): 0.7302101
# Predicted Q-value(mean): 0.5181022
# Real Q-value(mean): 0.49407935
# Loss of Q-Value(mean): 7.886153e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 63
# Reward value(mean): 0.72976667
# Predicted Q-value(mean): 0.5378359
# Real Q-value(mean): 0.49436164
# Loss of Q-Value(mean): 2.1250611e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 64
# Reward value(mean): 0.73203516
# Predicted Q-value(mean): 0.49893364
# Real Q-value(mean): 0.49552712
# Loss of Q-Value(mean): 1.6370346e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 65
# Reward value(mean): 0.7296785
# Predicted Q-value(mean): 0.5093073
# Real Q-value(mean): 0.49390304
# Loss of Q-Value(mean): 5.9468916e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 66
# Reward value(mean): 0.7295356
# Predicted Q-value(mean): 0.5067784
# Real Q-value(mean): 0.49192017
# Loss of Q-Value(mean): 1.7300388e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 67
# Reward value(mean): 0.72930384
# Predicted Q-value(mean): 0.5153891
# Real Q-value(mean): 0.4942997
# Loss of Q-Value(mean): 8.89446e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 68
# Reward value(mean): 0.7304046
# Predicted Q-value(mean): 0.52033025
# Real Q-value(mean): 0.49308085
# Loss of Q-Value(mean): 6.959495e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 69
# Reward value(mean): 0.73057574
# Predicted Q-value(mean): 0.5082668
# Real Q-value(mean): 0.4958333
# Loss of Q-Value(mean): 3.2451167e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 70
# Reward value(mean): 0.7294756
# Predicted Q-value(mean): 0.51909095
# Real Q-value(mean): 0.49443027
# Loss of Q-Value(mean): 1.1229876e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 71
# Reward value(mean): 0.7305902
# Predicted Q-value(mean): 0.49896094
# Real Q-value(mean): 0.4973779
# Loss of Q-Value(mean): 1.3549812e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 72
# Reward value(mean): 0.7294598
# Predicted Q-value(mean): 0.4873606
# Real Q-value(mean): 0.49586776
# Loss of Q-Value(mean): 2.6054945e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 73
# Reward value(mean): 0.7297293
# Predicted Q-value(mean): 0.49147522
# Real Q-value(mean): 0.49482778
# Loss of Q-Value(mean): 7.422977e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 74
# Reward value(mean): 0.7298992
# Predicted Q-value(mean): 0.4901329
# Real Q-value(mean): 0.49378276
# Loss of Q-Value(mean): 4.731741e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 75
# Reward value(mean): 0.7287671
# Predicted Q-value(mean): 0.5176587
# Real Q-value(mean): 0.49365968
# Loss of Q-Value(mean): 4.1523826e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 76
# Reward value(mean): 0.7297495
# Predicted Q-value(mean): 0.5226112
# Real Q-value(mean): 0.49421299
# Loss of Q-Value(mean): 5.3515273e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 77
# Reward value(mean): 0.72901046
# Predicted Q-value(mean): 0.4826292
# Real Q-value(mean): 0.49192664
# Loss of Q-Value(mean): 4.8876223e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 78
# Reward value(mean): 0.7298306
# Predicted Q-value(mean): 0.48760104
# Real Q-value(mean): 0.49442282
# Loss of Q-Value(mean): 4.4443e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 79
# Reward value(mean): 0.72935176
# Predicted Q-value(mean): 0.4766809
# Real Q-value(mean): 0.49583513
# Loss of Q-Value(mean): 1.3291539e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 80
# Reward value(mean): 0.7300562
# Predicted Q-value(mean): 0.5159479
# Real Q-value(mean): 0.49888763
# Loss of Q-Value(mean): 4.2057172e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 81
# Reward value(mean): 0.7291279
# Predicted Q-value(mean): 0.5085343
# Real Q-value(mean): 0.4949136
# Loss of Q-Value(mean): 9.989619e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 82
# Reward value(mean): 0.7299409
# Predicted Q-value(mean): 0.5205464
# Real Q-value(mean): 0.49329567
# Loss of Q-Value(mean): 6.0830453e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 83
# Reward value(mean): 0.73060304
# Predicted Q-value(mean): 0.51242167
# Real Q-value(mean): 0.49324727
# Loss of Q-Value(mean): 7.887486e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 84
# Reward value(mean): 0.7314298
# Predicted Q-value(mean): 0.49832606
# Real Q-value(mean): 0.49703854
# Loss of Q-Value(mean): 8.822764e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 85
# Reward value(mean): 0.73082006
# Predicted Q-value(mean): 0.52004516
# Real Q-value(mean): 0.49476
# Loss of Q-Value(mean): 1.5764594e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 86
# Reward value(mean): 0.7287873
# Predicted Q-value(mean): 0.5209907
# Real Q-value(mean): 0.49520126
# Loss of Q-Value(mean): 1.7768802e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 87
# Reward value(mean): 0.7310104
# Predicted Q-value(mean): 0.51505107
# Real Q-value(mean): 0.49606147
# Loss of Q-Value(mean): 1.0013327e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 88
# Reward value(mean): 0.72960126
# Predicted Q-value(mean): 0.5061823
# Real Q-value(mean): 0.49577492
# Loss of Q-Value(mean): 3.827011e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 89
# Reward value(mean): 0.73023254
# Predicted Q-value(mean): 0.48461092
# Real Q-value(mean): 0.49048355
# Loss of Q-Value(mean): 1.1887606e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 90
# Reward value(mean): 0.73073065
# Predicted Q-value(mean): 0.5210183
# Real Q-value(mean): 0.49460414
# Loss of Q-Value(mean): 7.08701e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 91
# Reward value(mean): 0.72892153
# Predicted Q-value(mean): 0.51932895
# Real Q-value(mean): 0.4937168
# Loss of Q-Value(mean): 4.0937607e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 92
# Reward value(mean): 0.7297627
# Predicted Q-value(mean): 0.52762514
# Real Q-value(mean): 0.49615538
# Loss of Q-Value(mean): 1.8615458e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 93
# Reward value(mean): 0.7308521
# Predicted Q-value(mean): 0.5176839
# Real Q-value(mean): 0.4953895
# Loss of Q-Value(mean): 2.2332186e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 94
# Reward value(mean): 0.73052996
# Predicted Q-value(mean): 0.5280799
# Real Q-value(mean): 0.49411678
# Loss of Q-Value(mean): 1.8406818e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 95
# Reward value(mean): 0.7302285
# Predicted Q-value(mean): 0.48828804
# Real Q-value(mean): 0.4961478
# Loss of Q-Value(mean): 6.4649985e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 96
# Reward value(mean): 0.73051184
# Predicted Q-value(mean): 0.5160965
# Real Q-value(mean): 0.49489248
# Loss of Q-Value(mean): 7.546353e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 97
# Reward value(mean): 0.729303
# Predicted Q-value(mean): 0.5159609
# Real Q-value(mean): 0.49295902
# Loss of Q-Value(mean): 7.1599825e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 98
# Reward value(mean): 0.72957504
# Predicted Q-value(mean): 0.5313907
# Real Q-value(mean): 0.49306622
# Loss of Q-Value(mean): 2.0656758e-05
# ----------------------------------------------------------------------------------------------------
# Iter: 99
# Reward value(mean): 0.7303006
# Predicted Q-value(mean): 0.51400304
# Real Q-value(mean): 0.49674752
# Loss of Q-Value(mean): 9.571962e-06
# ----------------------------------------------------------------------------------------------------
# Iter: 100
# Reward value(mean): 0.7298181
# Predicted Q-value(mean): 0.5123339
# Real Q-value(mean): 0.49572104
# Loss of Q-Value(mean): 3.977289e-06
# Keyboard Interrupt.

# %% [markdown]
# ### Visualize learning logs.
#
# Check the difference between inferneced Q-Values and real observed Q-Values.

# %%
def moving_avg(arr, window=5):
    return np.convolve(arr, np.ones(window) / window, mode='same')[window:-window]

plt.figure(figsize=(20, 10))
plt.plot(moving_avg(np.abs(DQN.q_logs_arr[:, 0] - DQN.q_logs_arr[:, 1])), label="Loss of Q-Values", color="red")
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# ### Inference the routes.
#
# After learning, `MazeDeepQNetwork` can provide a method `inference` for infernecing the routes.

# %%
# Reset Epsilon greedy rate.
DQN.epsilon_greedy_rate = 0.99
DQN.policy_sampler.inferencing_mode = True
DQN.policy_sampler.reset_agent_pos()

# Inference the routes.
state_arr_list, q_value_arr_list = DQN.inference(
    iter_n=1000
)

# %%
result_df_list = []
e_result_df_list = []
for i in range(len(state_arr_list)):
    arr_tuple = np.where(state_arr_list[i][0][0].asnumpy() == 1)

    x = arr_tuple[0][0]
    y = arr_tuple[1][0]
    
    q_value = q_value_arr_list[i].asnumpy()[0][0]
    result_df_list.append((x, y, q_value))

    col_list = []
    val_list = []
    for e in range(enemy_num):
        col_list.append("e_" + str(e+1) + "_x")
        col_list.append("e_" + str(e+1) + "_y")

        arr_tuple = np.where(state_arr_list[i][0, 2+e].asnumpy() == 1)
        x = arr_tuple[0][0]
        y = arr_tuple[1][0]
        val_list.append(x)
        val_list.append(y)

    e_result_df = pd.DataFrame([tuple(val_list)], columns=col_list)
    e_result_df = e_result_df.dropna()
    for e in range(enemy_num):
        e_result_df["e_" + str(e+1) + "_x"] = e_result_df["e_" + str(e+1) + "_x"].astype(int)
        e_result_df["e_" + str(e+1) + "_y"] = e_result_df["e_" + str(e+1) + "_y"].astype(int)

    e_result_df_list.append(e_result_df)

result_df = pd.DataFrame(result_df_list, columns=["x", "y", "q_value"])
e_result_df = pd.concat(e_result_df_list)
result_df = result_df.reset_index()
e_result_df = e_result_df.reset_index()
result_df = pd.concat([result_df, e_result_df], axis=1)

# %%
result_df.head(100)
# Out:
#     index  x  y   q_value  index  e_1_x  e_1_y  e_2_x  e_2_y
# 0       0  2  1  0.466693      0     14      9      7     14
# 1       1  4  1  0.538987      0     12      9      7     14
# 2       2  5  2  0.512993      0     12      7      7     15
# 3       3  5  3  0.472556      0     15      7      8      9
# 4       4  3  5  0.534158      0     16      7      9     10
# ..    ... .. ..       ...    ...    ...    ...    ...    ...
# 95     95  9  8  0.442739      0      2      5     11      2
# 96     96  9  7  0.425897      0      1      5     11      2
# 97     97  7  7  0.448632      0      1      3     13      3
# 98     98  8  7  0.501558      0      1      5     12      3
# 99     99  9  6  0.471522      0      2      5     11      3
#
# [100 rows x 9 columns]

# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

font = ImageFont.truetype("<path to your font>", 16)

img_list = []

for i in range(result_df.shape[0]):
    x = result_df.x.values[i]
    y = result_df.y.values[i]
    q = result_df.q_value.values[i]

    now_map_arr = DQN.policy_sampler.map_arr.copy()
    now_map_arr[x, y] = 2
    for e in range(enemy_num):
        e_x = result_df["e_" + str(e+1) + "_x"].values[i]
        e_y = result_df["e_" + str(e+1) + "_y"].values[i]
        now_map_arr[e_x, e_y] = 0.25

    now_map_arr = 255 * (now_map_arr - now_map_arr.min()) / (now_map_arr.max() - now_map_arr.min())
    img = Image.fromarray(np.uint8(now_map_arr))
    img = img.resize((400, 400))

    bg_img = Image.new("RGB", (420, 420), (0, 0, 0))
    bg_img.paste(img, (10, 10))
    draw = ImageDraw.Draw(bg_img)
    draw.multiline_text((5, 5), 'Inferenced Q-Value: ' + str(q), fill=(255, 255, 255), font=font)
    img_list.append(bg_img)

bg_img = Image.new("RGB", (420, 420), (0, 0, 0))
bg_img.paste(img, (10, 10))
draw = ImageDraw.Draw(bg_img)
if DQN.policy_sampler.END_STATE_list[0] == "Crash":
    draw.multiline_text((5, 5), 'Game Over !!', fill=(255, 255, 255), font=font)
elif DQN.policy_sampler.END_STATE_list[0] == "Goal":
    draw.multiline_text((5, 5), 'Goal !!', fill=(255, 255, 255), font=font)

[img_list.append(bg_img) for _ in range(50)]

img_list[0].save(
    'img/DQN_multi_agent_demo.gif',
    save_all=True,
    append_images=img_list[1:], 
    optimize=False, 
    duration=40, 
    loop=0
)

# %% [markdown]
# <img src='https://storage.googleapis.com/accel-brain-code/Reinforcement-Learning/img/DQN_multi_agent_demo_goal_enemy_2-compressed.gif?1'>

# %% [markdown]
# # References
#
# - Gupta, J. K., Egorov, M., & Kochenderfer, M. (2017, May). Cooperative multi-agent control using deep reinforcement learning. In International Conference on Autonomous Agents and Multiagent Systems (pp. 66-83). Springer, Cham.
# - Mnih, V., Kavukcuoglu, K., Silver, D., Graves, A., Antonoglou, I., Wierstra, D., & Riedmiller, M. (2013). Playing atari with deep reinforcement learning. arXiv preprint arXiv:1312.5602.
